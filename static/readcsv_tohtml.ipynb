# %%
import pandas as pd

# %%
filepath = "Resources/my_weather_data.csv"
df = pd.read_csv(filepath)

df
# Out:
#                       City Country        Date  Lattitude  Longitude  \
# 0               Bredasdorp      ZA  1644118454   -34.5322    20.0403
# 1             Constitución      CL  1644118736   -35.3333   -72.4167
# 2                   Albany      US  1644118738    42.6001   -73.9662
# 3                 Freeport      US  1644118457    40.6576   -73.5832
# 4                     Hilo      US  1644118740    19.7297  -155.0900
# ..                     ...     ...         ...        ...        ...
# 546  San Miguel de Tucumán      AR  1644119590   -26.8241   -65.2226
# 547         Port Macquarie      AU  1644119309   -31.4333   152.9167
# 548               Maragogi      BR  1644119102    -9.0122   -35.2225
# 549                   Yaan      NG  1644119594     7.3833     8.5667
# 550               Karratha      AU  1644119596   -20.7377   116.8463
#
#      Cloudiness  Humidity  Max Temperature  Wind Speed
# 0            64        95            20.16        2.36
# ...

# %%
df.to_html(index=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>City</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Lattitude</th>\n      <th>Longitude</th>\n      <th>Cloudiness</th>\n      <th>Humidity</th>\n      <th>Max Temperature</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>Bredasdorp</td>\n      <td>ZA</td>\n      <td>1644118454</td>\n      <td>-34.5322</td>\n      <td>20.0403</td>\n      <td>64</td>\n      <td>95</td>\n      <td>20.16</td>\n      <td>2.36</td>\n    </tr>\n    <tr>\n      <td>Constitución</td>\n      <td>CL</td>\n      <td>1644118736</td>\n      <td>-35.3333</td>\n      <td>-72.4167</td>\n      <td>0</td>\n      <td>64</td>\n      <td>16.60</td>\n      <td>3.67</td>\n    </tr>\n    <tr>\n      <td>Albany</td>\n      <td>US</td>\n      <td>1644118738</td>\n      <td>42.6001</td>\n      <td>-73.9662</td>\n      <td>5</td>\n      <td>76</td>\n      <td>-12.03</td>\n      <td>
# ...
